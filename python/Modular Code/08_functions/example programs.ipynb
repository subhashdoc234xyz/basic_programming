# %%
def main():
    x=int(input("what is x?"))
    print(" the squared value of x is",square(x))
def square(x):
    return x*x
main()
# Out:
#  the squared value of x is 3136

# %%
def hello():
    print("hello,")
    
name=input("Enter your name:" )
hello()
print(name)
# Out:
# hello,
# subhash

# %%
def hello(to ):#giving an parameter to the function
    print("hello,",to)

name=input("enter your name:")
hello(name)# copies the value of name to the parameter to in the function hello
# Out:
# hello, subhash

# %%
def hello(to="world"):#giving an parameter to the function
    print("hello,",to)
hello()#if no value is passed to the parameter to, it will take the default value "world"
name=input("enter your name:")
hello(name)# copies the value of name to the parameter to in the function hello
# Out:
# hello, world
# hello, subhash
